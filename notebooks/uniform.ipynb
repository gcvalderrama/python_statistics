# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (20,3)

# %%
numbers = np.random.uniform(low=0.0, high=1.0, size=10000)

# %%
_ = plt.hist(numbers, bins='auto')
plt.title("Histogram uniform")
plt.show()

# %%
sns.kdeplot(numbers)
# Out:
# <AxesSubplot: ylabel='Density'>
